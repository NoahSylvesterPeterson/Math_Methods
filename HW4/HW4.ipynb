# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

# %%
fig, ax = plt.subplots()
xdata, ydata = [], []
count =0 
b = 1
a = 1
l=1
nn = 2047
numterms = 30
x = np.linspace(-l,l,nn)
def f(x):
    return(np.where(abs(x) >= 1/b,0,1)*a*(1-b*np.abs(x)))
def b_n(n):
    #return(a*(-2*np.pi*n*np.cos(np.pi*n)+np.pi*n)/(n*n*np.pi*np.pi))
    #return(a*(1)/(n*np.pi))
    return(0)
def a_n(n):
    return(a*2*(1-np.cos(np.pi*n))/(n*n*np.pi*np.pi))
a_0 = 1
ln, = plt.plot(x, f(x)) # 'ro' for red circles

Ft, = plt.plot(x, a_0/2+ a_n(1)*np.cos(1*np.pi/l*x)+b_n(1)*np.sin(1*np.pi/l*x)) 


def init():
    ax.set_ylim(0,1)
    return ln,Ft

def update(frame):
    ydata= Ft.get_ydata()+ a_n(frame+1)*np.cos((frame+1)*np.pi/(l)*x)+ b_n(frame+1)*np.sin((frame+1)*np.pi/(l)*x)
    Ft.set_data(x, ydata)
    return ln,Ft

ani = FuncAnimation(fig, update, frames=np.linspace(1,numterms+1,numterms+1),
                    init_func=init, blit=True)
#plt.show()
# To save as a GIF:
ani.save('anim.gif', writer='pillow', fps=int(numterms/2))

# %%
fig, ax = plt.subplots()
xdata, ydata = [], []
count =0 
b = 1
a = 1
l=np.pi
nn = 2047
numterms = 30
x = np.linspace(-l,l,nn)
def f(x):
    return(np.where(abs(x) >= 1/b,0,1)*a*(1-b*np.abs(x)))
def b_n(n):
    #return(a*(-2*np.pi*n*np.cos(np.pi*n)+np.pi*n)/(n*n*np.pi*np.pi))
    #return(a*(1)/(n*np.pi))
    return(0)
def a_n(n):
    return(a*2*(1-np.cos(np.pi*n))/(n*n*np.pi*np.pi))
a_0 = 1
ln, = plt.plot(x, f(x)) # 'ro' for red circles

Ft, = plt.plot(x, a_0/2+ a_n(1)*np.cos(1*np.pi/(1/b)*x)+b_n(1)*np.sin(1*np.pi/(1/b)*x)) 


def init():
    ax.set_ylim(0,1)
    return ln,Ft

def update(frame):
    ydata= Ft.get_ydata()+ a_n(frame+1)*np.cos((frame+1)*np.pi/(1/b)*x)+ b_n(frame+1)*np.sin((frame+1)*np.pi/(1/b)*x)
    Ft.set_data(x, ydata)
    return ln,Ft

ani = FuncAnimation(fig, update, frames=np.linspace(1,numterms+1,numterms+1),
                    init_func=init, blit=True)
#plt.show()
# To save as a GIF:
ani.save('anim.gif', writer='pillow', fps=int(numterms/2))

# %%
fig, ax = plt.subplots()
xdata, ydata = [], []
count =0 
b = 1
a = 1
l=np.pi
nn = 2047
numterms = 30
x = np.linspace(-l,l,nn)
def f(x):
    return(np.where(abs(x) >= 1/b,0,1)*a*(1-b*np.abs(x)))
def b_n(n):
    #return(a*(-2*np.pi*n*np.cos(np.pi*n)+np.pi*n)/(n*n*np.pi*np.pi))
    #return(a*(1)/(n*np.pi))
    return(0)
def a_n(n):
    return(a*2*b*(1-np.cos(n/b))/(n*n)/(l))
a_0 = a/(np.pi*b)
ln, = plt.plot(x, f(x)) # 'ro' for red circles

Ft, = plt.plot(x, a_0/2+ a_n(1)*np.cos(1*np.pi/(l)*x)+b_n(1)*np.sin(1*np.pi/(1/b)*x)) 


def init():
    ax.set_ylim(-0,1)
    return ln,Ft

def update(frame):
    ydata= Ft.get_ydata()+ a_n(frame+1)*np.cos((frame+1)*np.pi/(l)*x)+ b_n(frame+1)*np.sin((frame+1)*np.pi/(1/b)*x)
    Ft.set_data(x, ydata)
    return ln,Ft

ani = FuncAnimation(fig, update, frames=np.linspace(1,numterms+1,numterms+1),
                    init_func=init, blit=True)
#plt.show()
# To save as a GIF:
ani.save('anim.gif', writer='pillow', fps=int(numterms/2))
